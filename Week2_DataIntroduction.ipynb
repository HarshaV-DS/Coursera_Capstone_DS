# %% [markdown]
# <h2>Data Introduction<h2>

# %% [markdown]
# <p>There are many popular datasets for predicting the Accident severity. Here, we are considering the dataset which is given by Coursera from all collisions provided by Seattle Police Department and recorded by Traffic Record. This includes all types of collisions. Collisions will display at the intersection or mid-block of a segment. Timeframe: 2004 to Present.</p>

# %% [markdown]
# <h3>Description of Data</h3>

# %% [markdown]
# <p>The Data-Collision dataset consists of total 40 Attributes and 194674 records, which is recorded within the time frame:2004-present. The below will be various forms of data:

# %%
import pandas as pd
dc=pd.read_csv("http://data-seattlecitygis.opendata.arcgis.com/datasets/5b5c745e0f1f48e7a53acec63a0022ab_0.csv")

# %% [markdown]
# <h4>Head of data</h4>

# %%
dc.head()
# Out:
#             X          Y  OBJECTID  INCKEY  COLDETKEY  REPORTNO     STATUS  \
# 0 -122.339735  47.625393         1  333240     334740   3851889  Unmatched
# 1 -122.326712  47.546101         2  333317     334817   3834541  Unmatched
# 2 -122.329062  47.586170         3    1367       1367   3671783    Matched
# 3 -122.337871  47.606478         4    1189       1189   3548948    Matched
# 4 -122.380021  47.688726         5   30400      30400  04046023  Unmatched
#
#        ADDRTYPE   INTKEY                                      LOCATION  ...  \
# 0  Intersection  28743.0                          9TH AVE N AND ROY ST  ...
# 1         Block      NaN  S MICHIGAN ST BETWEEN 5TH PL S AND 6TH AVE S  ...
# 2  Intersection  31348.0                    4TH AVE S AND S HOLGATE ST  ...
# 3         Block      NaN   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST  ...
# 4  Intersection  23863.0                    18TH AVE NW AND NW 83RD ST  ...
#
# ...

# %% [markdown]
# <h4>Data types of data</h4>

# %%
dc.dtypes
# Out:
# X                  float64
# Y                  float64
# OBJECTID             int64
# INCKEY               int64
# COLDETKEY            int64
# REPORTNO            object
# STATUS              object
# ADDRTYPE            object
# INTKEY             float64
# LOCATION            object
# EXCEPTRSNCODE       object
# EXCEPTRSNDESC       object
# SEVERITYCODE        object
# SEVERITYDESC        object
# COLLISIONTYPE       object
# PERSONCOUNT          int64
# PEDCOUNT             int64
# PEDCYLCOUNT          int64
# VEHCOUNT             int64
# INJURIES             int64
# SERIOUSINJURIES      int64
# FATALITIES           int64
# INCDATE             object
# INCDTTM             object
# JUNCTIONTYPE        object
# SDOT_COLCODE       float64
# SDOT_COLDESC        object
# INATTENTIONIND      object
# UNDERINFL           object
# WEATHER             object
# ROADCOND            object
# LIGHTCOND           object
# PEDROWNOTGRNT       object
# SDOTCOLNUM         float64
# ...

# %% [markdown]
# <h4>General description about data</h4>

# %%
dc.describe()
# Out:
#                    X              Y       OBJECTID         INCKEY  \
# count  213539.000000  213539.000000  221006.000000  221006.000000
# mean     -122.330749      47.620214  110503.500000  144381.354131
# std         0.030051       0.056027   63799.081134   88856.058154
# min      -122.419091      47.495573       1.000000    1001.000000
# 25%      -122.349280      47.577331   55252.250000   71538.250000
# 50%      -122.330348      47.616078  110503.500000  126992.500000
# 75%      -122.311998      47.664290  165754.750000  209230.750000
# max      -122.238949      47.734142  221006.000000  333357.000000
#
#            COLDETKEY         INTKEY    PERSONCOUNT       PEDCOUNT  \
# count  221006.000000   71728.000000  221006.000000  221006.000000
# mean   144607.382804   37614.282470       2.226686       0.038135
# std     89227.738059   51903.394045       1.470844       0.201806
# min      1001.000000   23807.000000       0.000000       0.000000
# ...

# %% [markdown]
# <h4>Number of Null values in all columns, which is displays integral vlaues:</h4>

# %%
dc.isna().sum()

# %% [markdown]
# <h3>Data Modelling</h3>
# <p>It involves many iterations, we should develop a model which is Supervised machine learning model, as it consists mainly od structured and labelled data. From the dataset we could see 37 attributes,for successful model development we should consider attributes. In order to improve the model we can consider only few attributes which plays important role on predicting the Accident severity effectively.</p>

# %% [markdown]
# <p>Before modelling we should pre-process the data. There are many irregularities in the data set, we should deal with missing values.</p>

# %% [markdown]
# <p>In the process of developing a model, we should divide the dataset into training dataset and testing dataset, because we should test the model to analyze the predictability

# %% [markdown]
# <p>So i am splitting the data in 70:30 ratio for better training and testing the model in order to achieve high accuracy in prediction. After developing a model, we should train with splitted training data and test it with testing data. After successfully developing a model, we should evaluate the model with supervised evaluation metrics like Jacards similarity index, F Score, Confusion matrix etc for better credibility of accuracy.</p>

# %% [markdown]
# <p>After completing all, we should make a report on approach as well as explaining details so that developed model should reflect its working.</p>
